# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# Data Colllection and Data Processing

# %%
cc_data=pd.read_csv("/content/creditcard.csv")
cc_data.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0     0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62    0.0
# 1     0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69    0.0
# 2     1 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66    0.0
# 3     1 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50    0.0
# 4     2 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
#number of rows and columns
cc_data.shape
# Out:
# (5974, 31)

# %%
#Describe given statastical method
cc_data.describe()
# Out:
#               Time           V1  ...       Amount        Class
# count  5974.000000  5974.000000  ...  5973.000000  5973.000000
# mean   2677.615501    -0.266159  ...    65.061811     0.000502
# std    1765.025532     1.395405  ...   192.490314     0.022407
# min       0.000000   -12.168192  ...     0.000000     0.000000
# 25%    1162.250000    -1.015749  ...     4.450000     0.000000
# 50%    2537.000000    -0.420703  ...    15.620000     0.000000
# 75%    3781.750000     1.115402  ...    56.660000     0.000000
# max    6645.000000     1.685314  ...  7712.430000     1.000000
#
# [8 rows x 31 columns]

# %%
#Checkin a missing values
cc_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# distribution of legit transaction and fraudulent transiction
cc_data['Class'].value_counts()
# Out:
# Class
# 0.0    5970
# 1.0       3
# Name: count, dtype: int64

# %% [markdown]
# 0--> Noramal Transaction
#
#
# 1--> Fraud Transaction

# %% [markdown]
# This dataset is highly unbalanced

# %%
  # seprating the data for analysis
  legit=cc_data[cc_data.Class==0]
  fraud=cc_data[cc_data.Class==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (5970, 31)
# (3, 31)

# %%
#statastical measures of data
legit.Amount.describe()
# Out:
# count    5970.000000
# mean       64.965707
# std       192.429839
# min         0.000000
# 25%         4.450000
# 50%        15.620000
# 75%        56.485000
# max      7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      3.000000
# mean     256.310000
# std      264.880121
# min        0.000000
# 25%      119.965000
# 50%      239.930000
# 75%      384.465000
# max      529.000000
# Name: Amount, dtype: float64

# %%
# compare of values for both transaction
cc_data.groupby('Class').mean()
# Out:
#              Time        V1        V2  ...       V27       V28      Amount
# Class                                  ...
# 0.0    2677.40201 -0.264965  0.285625  ...  0.025238  0.006163   64.965707
# 1.0    1780.00000 -2.553039  0.184644  ...  0.015979 -0.086847  256.310000
#
# [2 rows x 30 columns]

# %% [markdown]
# Under-sampling

# %% [markdown]
# Build sample dataset containing similiar distribution of normal transaction and Fraudulent Transactions

# %% [markdown]
# Number of Fraudelent Transiction--> 492

# %%
legit_sample=legit.sample(n=492)

# %% [markdown]
# Conactenating two DataFrames

# %%
new_dataset=pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#       Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 284    204 -0.938226  0.104717  1.309642  ... -0.058198  0.107996   39.94    0.0
# 2502  2073  0.522995 -1.009796  1.050363  ...  0.031153  0.070760  278.00    0.0
# 4326  3760  1.401276 -0.683958 -0.915143  ... -0.019937  0.015447   42.00    0.0
# 2964  2507 -2.184272  0.978212  3.232465  ... -0.232148 -0.537802   64.31    0.0
# 5534  5618 -8.053149  7.045990 -1.102994  ...  1.180975  0.194628    5.49    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#       Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 345    256 -1.377245  0.714823  2.507513  ... -0.032235  0.139841   13.53    0.0
# 168    107  1.175125  0.661341 -0.477476  ...  0.051425  0.041876    1.00    0.0
# 541    406 -2.312227  1.951992 -1.609851  ...  0.261145 -0.143276    0.00    1.0
# 623    472 -3.043541 -3.157307  1.088463  ... -0.252773  0.035764  529.00    1.0
# 4920  4462 -2.303350  1.759247 -0.359745  ...  0.039566 -0.153029  239.93    1.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    492
# 1.0      3
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#               Time        V1        V2  ...       V27       V28     Amount
# Class                                   ...
# 0.0    2715.857724 -0.366950  0.347693  ...  0.040217 -0.003058   78.19628
# 1.0    1780.000000 -2.553039  0.184644  ...  0.015979 -0.086847  256.31000
#
# [2 rows x 30 columns]

# %% [markdown]
# Spliting the data into Features an target

# %%
X=new_dataset.drop('Class',axis=1)
Y=new_dataset['Class']

# %% [markdown]
# Splt into Train and Test

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %% [markdown]
# Model training

# %% [markdown]
# Logistic Regression

# %%
model=LogisticRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evalution

# %%
# accuracy on training data
X_train_prediction=model.predict(X_train)
training_data_accuracy=accuracy_score(X_train_prediction,Y_train)

# %%
print('Accuracy on Training data :',training_data_accuracy)
# Out:
# Accuracy on Training data : 1.0

# %%
# accuracy on test data
X_test_prediction=model.predict(X_test)
test_data_accuracy=accuracy_score(X_test_prediction,Y_test)

# %%
print('Accuracy on Test data :',test_data_accuracy)
# Out:
# Accuracy on Test data : 0.9696969696969697

# %% [markdown]
# Making Predictive System

# %%
input_data=(472,-3.043541,-3.157307,1.088463,2.288644,1.359805,-1.064823,0.325574,-0.067794,-0.270953,-0.838587,-0.414575,-0.503141,0.676502,-1.692029,2.000635,0.666780,0.599717,1.725321,0.283345,2.102339,0.661696	,0.435477	,1.375966,-0.293803,0.279798,-0.145362,-0.252773,0.035764,529.00)
input_data_as_numpy_array=np.asarray(input_data)
input_data_reshaped=input_data_as_numpy_array.reshape(1,-1)
prediction=model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]==0):
  print('It is an legit credt card')
else:
  print('It is an Fraud credit card',)
# Out:
# [1.]
# It is an Fraud credit card
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
